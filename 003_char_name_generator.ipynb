# %%
names = {
    'Cassian Andor': 'Cassian Andor',
    'Dedra Meero': 'Dedra Meero',
    'Syril Karn': 'Syril Karn',
    'Luthen Rael': 'Luthen Rael',
    'Bix Caleen': 'Bix Caleen',
    'Mon Mothma': 'Mon Mothma',
    'Major Partagaz': 'Major Partagaz',
    'Vel Sartha': 'Vel Sartha',
    'Wilmon': 'Wilmon',
    'Kleya Marki': 'Kleya Marki',
    'Attendant Heert': 'Attendant Heert',
    'Supervisor Heert': 'Supervisor Heert',
    'B2EMO': 'B2EMO',
    'Supervisor Lagret': 'Supervisor Lagret',
    'Perrin Fertha': 'Perrin Fertha',
    'Cinta Kaz': 'Cinta Kaz',
    'Brasso': 'Brasso',
    'Eedy Karn': 'Eedy Karn',
    'Supervisor Lonni Jung': 'Supervisor Lonni Jung',
    'Leida': 'Leida',
    'Kloris': 'Kloris',
    'Erskin Semaj': 'Erskin Semaj',
    'Davo Sculdun': 'Davo Sculdun',
    'Tay Kolma': 'Tay Kolma',
    'Two Tubes': 'Two Tubes',
    'Alien Bailiff': 'Alien Bailiff',
    'Dreena': 'Dreena',
    'Dilan': 'Dilan',
    'Leeza': 'Leeza',
    'Enza Rylanz': 'Enza Rylanz',
    'Samm': 'Samm',
    'Corv': 'Corv',
    'Carro Rylanz': 'Carro Rylanz',
    'Melshi': 'Melshi',
    'Lieutenant Supervisor Blevin': 'Lieutenant Supervisor Blevin',
    'Tazi': 'Tazi',
    'Sergeant Linus Mosk': 'Sergeant Linus Mosk',
    'Capso': 'Capso',
    'Doctor Gorst': 'Doctor Gorst',
    'Captain Vanis Tigo': 'Captain Vanis Tigo',
    'Salman Paak': 'Salman Paak',
    'Maarva Andor': 'Maarva Andor',
    'Runai Sculdun': 'Runai Sculdun',
    'Rashi': 'Rashi',
    'Karis Nemik': 'Karis Nemik',
    'Alien Grappler': 'Alien Grappler',
    'Oathkeeper': 'Oathkeeper',
    'Supervisor Grandi': 'Supervisor Grandi',
    'Xanwan': 'Xanwan',
    'Chandrilan Girl': 'Chandrilan Girl',
    'Lieutenant Keysax': 'Lieutenant Keysax',
    'Nurchi': 'Nurchi',
    'Lezine': 'Lezine',
    'Stekan Sculdun': 'Stekan Sculdun',
    'Saw Gerrera': 'Saw Gerrera',
    'K-2SO': 'K-2SO',
    'Kassa': 'Kassa',
    'Arvel Skeen': 'Arvel Skeen',
    'Taramyn Barcona': 'Taramyn Barcona',
    'Ulaf': 'Ulaf',
    'Box Guard Left': 'Box Guard Left',
    'Senator Dasi Oran': 'Senator Dasi Oran',
    'Lieutenant Gorn': 'Lieutenant Gorn',
    'Box Guard Right': 'Box Guard Right',
    'Box Guard #1': 'Box Guard #1',
    'Grymish': 'Grymish',
    'BOS #1': 'BOS #1',
    'Kino Loy': 'Kino Loy',
    'BOS #2': 'BOS #2',
    'Jemboc': 'Jemboc',
    'Timm Karlo': 'Timm Karlo',
    'Voice of God': 'Voice of God',
    'Time Grappler': 'Time Grappler',
    'Ham': 'Ham',
    'Birnok': 'Birnok',
    'Table #2': 'Table #2',
    'Talia': 'Talia',
    'Clem Andor': 'Clem Andor',
    'Xaul': 'Xaul',
    'Table #1': 'Table #1',
    'Taga': 'Taga',
    'Table #3': 'Table #3',
    'Table #4': 'Table #4',
    'Pegla': 'Pegla',
    'Jezzi': 'Jezzi',
    'Thela': 'Thela',
    'Table #7': 'Table #7',
    'Beela': 'Beela',
    'Zinska': 'Zinska',
    'Aunt Squidna': 'Aunt Squidna',
    'Uncle Sordo': 'Uncle Sordo',
    'Father': 'Father',
    'Son': 'Son',
    'Freedi Pamular': 'Freedi Pamular',
    'Senator #5': 'Senator #5',
    'Alpha #1': 'Alpha #1',
    'Captain Kaido': 'Captain Kaido',
    'Colonel Yularen': 'Colonel Yularen',
    'Alpha #4': 'Alpha #4',
    'Flob': 'Flob',
    'Reporter #2': 'Reporter #2',
    'Bail Organa': 'Bail Organa',
    'Chief Hyne': 'Chief Hyne',
    'Alpha #2': 'Alpha #2',
    'Attendant Felzonis': 'Attendant Felzonis',
    'Hostess': 'Hostess',
    'Snee': 'Snee',
    'Sergeant Bloy': 'Sergeant Bloy',
    'Alpha #5': 'Alpha #5',
    'Gerdis': 'Gerdis',
    'Flek': 'Flek',
    'Corporal #1': 'Corporal #1',
    'Corporal Kimzi': 'Corporal Kimzi',
    'Kellen': 'Kellen',
    'Mishko': 'Mishko',
    'Bardi': 'Bardi',
    'Snur': 'Snur',
    'West-4': 'West-4',
    'Willi': 'Willi',
    'West-3': 'West-3',
    'Officer #1': 'Officer #1',
    'Bayso': 'Bayso',
    'North-1': 'North-1',
    'Young Cassian': 'Young Cassian',
    'East-1': 'East-1',
    'Officer #2': 'Officer #2',
    'North-3': 'North-3',
    'Doctor Rhasiv': 'Doctor Rhasiv',
    'Rowd': 'Rowd',
    'Plug': 'Plug',
    'Tick': 'Tick',
    'Officer #3': 'Officer #3',
    'Nazy': 'Nazy',
    'Delivery Guard #1': 'Delivery Guard #1',
    'Neek': 'Neek',
    'Officer #4': 'Officer #4',
    'Console Guard #1': 'Console Guard #1',
    'Delivery Guard #2': 'Delivery Guard #2',
    'Intake Warden': 'Intake Warden',
    'Pluti': 'Pluti',
    'Aneth': 'Aneth',
    'Musk': 'Musk',
    'Flu': 'Flu',
    'Orson Krennic': 'Orson Krennic',
    'Lieutenant Krole': 'Lieutenant Krole',
    'Doctor Mullmoy': 'Doctor Mullmoy',
    'Soldier #2': 'Soldier #2',
    'Lieutenant Moy': 'Lieutenant Moy',
    'Corporal Pyke': 'Corporal Pyke',
    'Soldier #1': 'Soldier #1',
    'Partisan': 'Partisan',
    'Kid': 'Kid',
    'Transpo Guard #1': 'Transpo Guard #1',
    'Niya': 'Niya',
    'Doorman': 'Doorman',
    'Bartender': 'Bartender',
    'Talking Head': 'Talking Head',
    "Niya's Co-Worker": "Niya's Co-Worker",
    'Kravas': 'Kravas',
    'Newscaster': 'Newscaster',
    'Farmer #1': 'Farmer #1',
    'Senator #6': 'Senator #6',
    'Verlo': 'Verlo',
    'Commandant Jayhold Beehaz': 'Commandant Jayhold Beehaz',
    'Senator #7': 'Senator #7',
    'Chieftan': 'Chieftan',
    'Niki': 'Niki',
    'Fellow Prisoner': 'Fellow Prisoner',
    'Gani': 'Gani',
    'Bon': 'Bon',
    'Colonel Petigar': 'Colonel Petigar',
    'Farmer #2': 'Farmer #2',
    'Kerri': 'Kerri',
    'Dewi Pamular': 'Dewi Pamular',
    'Console Tech': 'Console Tech',
    'Wandering Soldier': 'Wandering Soldier',
    'Roboda Beehaz': 'Roboda Beehaz',
    'Private #1': 'Private #1',
    'Bodega Vendor': 'Bodega Vendor',
    'Leonart Beehaz': 'Leonart Beehaz',
    'Private #2': 'Private #2',
    'Running Soldier': 'Running Soldier',
    'Selko': 'Selko',
    'Door Sentry': 'Door Sentry',
    'Charval': 'Charval',
    'Corporal #4': 'Corporal #4',
    'Pono': 'Pono',
    'Neighbour': 'Neighbour',
    'Galley Soldier #2': 'Galley Soldier #2',
    'Nervous Soldier': 'Nervous Soldier',
    'Galley Soldier #1': 'Galley Soldier #1',
    'Senator Gane': 'Senator Gane',
    'Senator Nico': 'Senator Nico',
    'Corporal #2': 'Corporal #2',
    'Tech Op #1': 'Tech Op #1',
    'Senate Officer': 'Senate Officer',
    'Tech Op #2': 'Tech Op #2',
    'Lounge #1': 'Lounge #1',
    'Gunner #1': 'Gunner #1',
    'Lounge #2': 'Lounge #2',
    'Soldier #1': 'Soldier #1',
    'Senator #2': 'Senator #2',
    'Hotel Clerk': 'Hotel Clerk',
    'Senate Reporter #1': 'Senate Reporter #1',
    'Mobile Radioman': 'Mobile Radioman',
    'Astro-Traffic Control Officer': 'Astro-Traffic Control Officer',
    'Senator #3': 'Senator #3',
    'Force Healer': 'Force Healer',
    'Senate Reporter #2': 'Senate Reporter #2',
    'General Davits Draven': 'General Davits Draven',
    'Senator #4': 'Senator #4',
    'Senator Karloo': 'Senator Karloo',
    'Vetch': 'Vetch',
    'Moffi': 'Moffi',
    'Toffi': 'Toffi',
    'Senator Erveen': 'Senator Erveen',
    'Granik': 'Granik',
    'Sunif Brecanti': 'Sunif Brecanti',
    'New Employee': 'New Employee',
    'Console #1': 'Console #1',
    'Imperial Sniper': 'Imperial Sniper',
    'Captain Elk': 'Captain Elk',
    'Cleave': 'Cleave',
    'Elector': 'Elector',
    'Jeen': 'Jeen',
    'Hotel Clerk': 'Hotel Clerk',
    'Executive Officer': 'Executive Officer',
    'Crab': 'Crab',
    'Other Driver': 'Other Driver',
    'Weapons Spec': 'Weapons Spec',
    'Imperial Officer': 'Imperial Officer',
    'Intake Sergeant': 'Intake Sergeant',
    'Windi': 'Windi',
    'Pit #1': 'Pit #1',
    'Recon Soldier A': 'Recon Soldier A',
    'Shambo': 'Shambo',
    'Pit #2': 'Pit #2',
    'Recon Soldier B': 'Recon Soldier B',
    'Osar': 'Osar',
    'Sergeant Stang': 'Sergeant Stang',
    'Judge': 'Judge',
    'Wife': 'Wife',
    'Bartender': 'Bartender',
    'Old Woman': 'Old Woman',
    'Dewi': 'Dewi',
    'Prosecutor': 'Prosecutor',
    'Engineer Officer': 'Engineer Officer',
    'Nervous Woman': 'Nervous Woman',
    'Radio Soldier': 'Radio Soldier',
    'Tenek': 'Tenek',
    'Freedi': 'Freedi',
    'Science Officer': 'Science Officer',
    'Husband': 'Husband',
    'Admiral Daysar': 'Admiral Daysar'
}

# %%
character_dict = {}

for name in names:
    character_dict[name] = name
    parts = name.split()
    if len(parts) > 1:
        character_dict[parts[0]] = name

import pprint
pprint.pprint(character_dict)
# Out:
# {'Admiral': 'Admiral Daysar',
#  'Admiral Daysar': 'Admiral Daysar',
#  'Alien': 'Alien Grappler',
#  'Alien Bailiff': 'Alien Bailiff',
#  'Alien Grappler': 'Alien Grappler',
#  'Alpha': 'Alpha #5',
#  'Alpha #1': 'Alpha #1',
#  'Alpha #2': 'Alpha #2',
#  'Alpha #4': 'Alpha #4',
#  'Alpha #5': 'Alpha #5',
#  'Aneth': 'Aneth',
#  'Arvel': 'Arvel Skeen',
#  'Arvel Skeen': 'Arvel Skeen',
#  'Astro-Traffic': 'Astro-Traffic Control Officer',
#  'Astro-Traffic Control Officer': 'Astro-Traffic Control Officer',
#  'Attendant': 'Attendant Felzonis',
#  'Attendant Felzonis': 'Attendant Felzonis',
#  'Attendant Heert': 'Attendant Heert',
#  'Aunt': 'Aunt Squidna',
#  'Aunt Squidna': 'Aunt Squidna',
#  'B2EMO': 'B2EMO',
#  'BOS': 'BOS #2',
#  'BOS #1': 'BOS #1',
#  'BOS #2': 'BOS #2',
#  'Bail': 'Bail Organa',
#  'Bail Organa': 'Bail Organa',
#  'Bardi': 'Bardi',
#  'Bartender': 'Bartender',
#  'Bayso': 'Bayso',
#  'Beela': 'Beela',
#  'Birnok': 'Birnok',
#  'Bix': 'Bix Caleen',
# ...
